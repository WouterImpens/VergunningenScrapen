# %% [markdown]
# ## Info vergunningen scrapen
# Na het publiceren van WFS wordt het mogelijk  om de vergunningen op automatische wijze binnen te halen.
# De info in de WFS is echter beperkt, voorliggende onderzoek wil nagaan in welke mate het mogelijk is om
# bijkomende info (te vinden op het inzage loket onder de vorm van pdf) op te halen en te analyseren op
# automatische wijze.

# %%
# Nodige bib
import pandas as pd
import sqlalchemy
# %load_ext sql

# %%
# Verbinding met DuckDB database
# %sql duckdb:///C:/Users/d08909/Documents/01_WERKMAP/VERGUNNINGEN_SCRAPEN/2_WERKDATA/DB/vergunningen_test.duckdb
# Out:
# Connecting to 'duckdb:///C:/Users/d08909/Documents/01_WERKMAP/VERGUNNINGEN_SCRAPEN/2_WERKDATA/DB/vergunningen_test.duckdb'

# %%
# Verkennen van de database
# %sql SELECT * from vergunningen_leuven_import LIMIT 5;
# Out:
# Running query in 'duckdb:///C:/Users/d08909/Documents/01_WERKMAP/VERGUNNINGEN_SCRAPEN/2_WERKDATA/DB/vergunningen_test.duckdb'
# ...

# %% [markdown]
# ### Selectie van de nodige kolommen en filteren van de data op actieve vergunningen

# %%
# %sql select distinct huidige_toestand from vergunningen_leuven_import;
# Out:
# Running query in 'duckdb:///C:/Users/d08909/Documents/01_WERKMAP/VERGUNNINGEN_SCRAPEN/2_WERKDATA/DB/vergunningen_test.duckdb'
# +-----------------------------------+
# |          huidige_toestand         |
# +-----------------------------------+
# |             Stopgezet             |
# |         Niet rechtsgeldig         |
# |             Vergunning            |
# |     In behandeling (na beroep)    |
# |      Geen beslissing genomen      |
# |              Aktename             |
# |             Weigering             |
# | In behandeling (in eerste aanleg) |
# +-----------------------------------+
